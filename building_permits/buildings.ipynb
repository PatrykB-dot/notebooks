# %%
import pandas as pd
import numpy as np

# %%
sf_permits = pd.read_csv("data/Building_Permits.csv")
# Out:
# C:\Users\Patryk\AppData\Local\Temp\ipykernel_11532\1298163522.py:1: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   sf_permits = pd.read_csv("data/Building_Permits.csv")

# %%
# take a look to data, get 5 random columns 
sf_permits.sample(5)
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 175073  201702159508            3  additions alterations or repairs
# 105444       M636767            8            otc alterations permit
# 163922  201707192397            8            otc alterations permit
# 177237  201706159435            8            otc alterations permit
# 10753   201304255458            8            otc alterations permit
#
#        Permit Creation Date  Block   Lot  Street Number Street Number Suffix  \
# 175073           02/15/2017  0462A   034            270                  NaN
# 105444           11/10/2015   0983   022            104                  NaN
# 163922           07/19/2017   0045   069           2555                  NaN
# 177237           06/15/2017   3547  018A            315                  NaN
# 10753            04/25/2013   1525   035            440                  NaN
#
#         Street Name Street Suffix  ...  Existing Construction Type  \
# ...

# %% [markdown]
# Check missing points

# %%
# get the number of 
missing_values_count = sf_permits.isnull().sum()

# %% [markdown]
# I want to see how many missing values i have in dataframe

# %%
total_cells = np.prod(sf_permits.shape)
total_missing = missing_values_count.sum()

# percent of data that is missing
(total_missing/total_cells) * 100
# Out:
# 26.26002315058403

# %% [markdown]
# Almost 26 percent of data has null values

# %% [markdown]
# I want to use dropna function and compare data sets with null and without null values

# %%
columns_with_na_dropped = sf_permits.dropna(axis=1)
columns_with_na_dropped.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Name Current Status  \
# 0           05/06/2015  0326  023            140       Ellis        expired
# 1           04/19/2016  0306  007            440       Geary         issued
# 2           05/27/2016  0595  203           1647     Pacific      withdrawn
# 3           11/07/2016  0156  011           1230     Pacific       complete
# 4           11/28/2016  0342  001            950      Market         issued
#
#   Current Status Date  Filed Date      Record ID
# 0          12/21/2017  05/06/2015  1380611233945
# ...

# %%
# just how much data did i lose?
print("Columns in original dataset: %d \n" % sf_permits.shape[1])
print("Columns with na's dropped: %d" % columns_with_na_dropped.shape[1])
# Out:
# Columns in original dataset: 43
#
# Columns with na's dropped: 12

# %% [markdown]
# Looks like i lost many columns by dropping na values by this method

# %% [markdown]
# Filling missing values

# %%
subset_sf_permits = sf_permits.loc[:, 'Existing Construction Type':'Record ID'].head()
subset_sf_permits
# Out:
#    Existing Construction Type Existing Construction Type Description  \
# 0                         3.0                          constr type 3
# 1                         3.0                          constr type 3
# 2                         1.0                          constr type 1
# 3                         5.0                         wood frame (5)
# 4                         3.0                          constr type 3
#
#    Proposed Construction Type Proposed Construction Type Description  \
# 0                         NaN                                    NaN
# 1                         NaN                                    NaN
# 2                         1.0                          constr type 1
# 3                         5.0                         wood frame (5)
# 4                         NaN                                    NaN
#
#   Site Permit  Supervisor District Neighborhoods - Analysis Boundaries  \
# ...

# %%
subset_sf_permits.fillna(method = 'bfill', axis=0).fillna(0)
# Out:
#    Existing Construction Type Existing Construction Type Description  \
# 0                         3.0                          constr type 3
# 1                         3.0                          constr type 3
# 2                         1.0                          constr type 1
# 3                         5.0                         wood frame (5)
# 4                         3.0                          constr type 3
#
#    Proposed Construction Type Proposed Construction Type Description  \
# 0                         1.0                          constr type 1
# 1                         1.0                          constr type 1
# 2                         1.0                          constr type 1
# 3                         5.0                         wood frame (5)
# 4                         0.0                                      0
#
#    Site Permit  Supervisor District Neighborhoods - Analysis Boundaries  \
# ...
